# %%
# !pip install playwright
# Out:
# Collecting playwright
#   Using cached playwright-1.52.0-py3-none-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting pyee<14,>=13 (from playwright)
#   Using cached pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting greenlet<4.0.0,>=3.1.1 (from playwright)
#   Downloading greenlet-3.2.3-cp313-cp313-macosx_11_0_universal2.whl.metadata (4.1 kB)
# Requirement already satisfied: typing-extensions in ./env/lib/python3.13/site-packages (from pyee<14,>=13->playwright) (4.13.2)
# Using cached playwright-1.52.0-py3-none-macosx_11_0_arm64.whl (38.0 MB)
# Downloading greenlet-3.2.3-cp313-cp313-macosx_11_0_universal2.whl (270 kB)
# Using cached pyee-13.0.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, greenlet, playwright
# Successfully installed greenlet-3.2.3 playwright-1.52.0 pyee-13.0.0
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !playwright install
# Out:
# Downloading Firefox 137.0 (playwright build v1482) from https://cdn.playwright.dev/dbazure/download/playwright/builds/firefox/1482/firefox-mac-arm64.zip
# 85 MiB [                    ] 0% 0.0s85 MiB [                    ] 0% 190.4s85 MiB [                    ] 0% 153.9s85 MiB [                    ] 0% 133.2s85 MiB [                    ] 0% 191.0s85 MiB [                    ] 0% 157.1s85 MiB [                    ] 0% 132.8s85 MiB [                    ] 0% 155.8s85 MiB [                    ] 0% 144.7s85 MiB [                    ] 0% 132.2s85 MiB [                    ] 0% 122.8s85 MiB [                    ] 0% 115.9s85 MiB [                    ] 0% 109.9s85 MiB [                    ] 0% 123.2s85 MiB [                    ] 0% 117.0s85 MiB [                    ] 0% 124.2s85 MiB [                    ] 0% 118.2s85 MiB [                    ] 0% 113.6s85 MiB [                    ] 0% 110.9s85 MiB [                    ] 0% 105.8s85 MiB [                    ] 1% 102.5s85 MiB [                    ] 1% 101.5s85 MiB [                    ] 1% 106.7s85 MiB [                    ] 1% 104.7s85 MiB [                    ] 1% 104.3s85 MiB [                    ] 1% 101.1s85 MiB [                    ] 1% 106.9s85 MiB [                    ] 1% 102.9s85 MiB [                    ] 1% 100.4s85 MiB [                    ] 1% 96.7s85 MiB [                    ] 1% 93.9s85 MiB [                    ] 1% 90.4s85 MiB [                    ] 1% 89.4s85 MiB [                    ] 1% 86.7s85 MiB [                    ] 1% 91.2s85 MiB [                    ] 1% 90.2s85 MiB [                    ] 2% 88.5s85 MiB [                    ] 2% 88.2s85 MiB [                    ] 2% 90.9s85 MiB [                    ] 2% 91.6s85 MiB [                    ] 2% 94.4s85 MiB [                    ] 2% 93.7s85 MiB [                    ] 2% 97.0s85 MiB [                    ] 2% 97.9s85 MiB [                    ] 2% 96.8s85 MiB [                    ] 2% 96.5s85 MiB [                    ] 2% 99.4s85 MiB [                    ] 2% 97.9s85 MiB [=                   ] 2% 95.6s85 MiB [=                   ] 2% 96.4s85 MiB [=                   ] 2% 94.2s85 MiB [=                   ] 2% 92.2s85 MiB [=                   ] 2% 90.2s85 MiB [=                   ] 2% 88.5s85 MiB [=                   ] 3% 89.6s85 MiB [=                   ] 3% 87.7s85 MiB [=                   ] 3% 86.3s85 MiB [=                   ] 3% 90.5s85 MiB [=                   ] 3% 90.9s85 MiB [=                   ] 3% 92.0s85 MiB [=                   ] 3% 92.3s85 MiB [=                   ] 3% 94.5s85 MiB [=                   ] 3% 95.0s85 MiB [=                   ] 3% 95.2s85 MiB [=                   ] 3% 95.5s85 MiB [=                   ] 3% 97.8s85 MiB [=                   ] 
    ] 1% 63.4s74.3 MiB [                    ] 1% 62.3s74.3 MiB [                    ] 1% 61.1s74.3 MiB [                    ] 1% 60.7s74.3 MiB [                    ] 2% 60.0s74.3 MiB [                    ] 2% 60.5s74.3 MiB [                    ] 2% 59.6s74.3 MiB [                    ] 2% 58.7s74.3 MiB [                    ] 2% 58.2s74.3 MiB [                    ] 2% 57.2s74.3 MiB [                    ] 2% 56.5s74.3 MiB [                    ] 2% 57.3s74.3 MiB [                    ] 2% 56.9s74.3 MiB [=                   ] 2% 56.1s74.3 MiB [=                   ] 2% 56.3s74.3 MiB [=                   ] 2% 55.8s74.3 MiB [=                   ] 2% 55.5s74.3 MiB [=                   ] 2% 55.3s74.3 MiB [=                   ] 2% 55.6s74.3 MiB [=                   ] 2% 55.4s74.3 MiB [=                   ] 2% 55.3s74.3 MiB [=                   ] 2% 55.1s74.3 MiB [=                   ] 3% 54.8s74.3 MiB [=                   ] 3% 55.0s74.3 MiB [=                   ] 3% 54.9s74.3 MiB [=                   ] 3% 55.0s74.3 MiB [=                   ] 3% 55.1s74.3 MiB [=                   ] 3% 54.7s74.3 MiB [=                   ] 3% 54.6s74.3 MiB [=                   ] 3% 55.0s74.3 MiB [=                   ] 3% 54.2s74.3 MiB [=                   ] 3% 54.0s74.3 MiB [=                   ] 3% 54.1s74.3 MiB [=                   ] 3% 54.2s74.3 MiB [=                   ] 3% 54.3s74.3 MiB [=                   ] 3% 54.5s74.3 MiB [=                   ] 3% 54.6s74.3 MiB [=                   ] 3% 54.4s74.3 MiB [=                   ] 3% 54.2s74.3 MiB [=                   ] 3% 54.0s74.3 MiB [=                   ] 4% 53.9s74.3 MiB [=                   ] 4% 53.6s74.3 MiB [=                   ] 4% 53.8s74.3 MiB [=                   ] 4% 53.3s74.3 MiB [=                   ] 4% 53.2s74.3 MiB [=                   ] 4% 53.4s74.3 MiB [=                   ] 4% 53.2s74.3 MiB [=                   ] 4% 53.0s74.3 MiB [=                   ] 4% 52.9s74.3 MiB [=                   ] 4% 52.4s74.3 MiB [=                   ] 4% 52.0s74.3 MiB [=                   ] 4% 52.2s74.3 MiB [=                   ] 4% 52.3s74.3 MiB [=                   ] 4% 51.9s74.3 MiB [=                   ] 4% 51.7s74.3 MiB [=                   ] 4% 51.4s74.3 MiB [=                   ] 5% 51.1s74.3 MiB [=                   ] 5% 50.9s74.3 MiB [=                   ] 5% 50.7 ...
# Webkit 18.4 (playwright build v2158) downloaded to /Users/yasmine/Library/Caches/ms-playwright/webkit-2158

# %%
import asyncio
from playwright.async_api import async_playwright

async def main():
    async with async_playwright() as p:
        await run(p)

await main()
# Out:
# ✅ Chrome lancé avec profil temporaire
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 8
#       5     async with async_playwright() as p:
#       6         await run(p)
# ----> 8 await main()
#
# Cell In[7], line 6, in main()
#       4 async def main():
#       5     async with async_playwright() as p:
# ----> 6         await run(p)
#
# File ~/Desktop/déploiement_industrialisation_IA/login.py:31, in run(playwright)
#      28     print(f"❌ Erreur de lancement : {e}")
#      29     return
# ---> 31 page = browser.pages[0] if browser.pages else browser.new_page()
#      33 try:
#      34     # Aller sur le site
#      35     page.goto("https://everywatch.com", wait_until="networkidle")
#
# AttributeError: 'coroutine' object has no attribute 'pages'
